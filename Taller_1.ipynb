# %% [markdown]
# <a href="https://colab.research.google.com/github/YuliethRojas/TalentoTech/blob/Actividades/Taller_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import openpyxl as op

# %%
df=pd.read_excel("/content/drive/MyDrive/BD Yulieth/example_ventas.xlsx")

# %%
df
# Out:
#         Fecha   Region      Producto Vendedor  Ventas
# 0  2024-01-31  Central    Accesorios    David    8287
# 1  2024-02-01  Central    Accesorios    Karen    6909
# 2  2024-02-02  Central  Dispositivos    David   11420
# 3  2024-02-03  Central  Dispositivos    Karen   12948
# 4  2024-02-04  Central      Sistemas    David   20098
# 5  2024-02-05  Central      Sistemas    Karen   30633
# 6  2024-02-06     Este    Accesorios      Ana    9323
# 7  2024-02-07     Este    Accesorios    Lucas    7667
# 8  2024-02-08     Este  Dispositivos      Ana   10348
# 9  2024-02-09     Este  Dispositivos    Lucas    9312
# 10 2024-02-10     Este      Sistemas      Ana   13531
# 11 2024-02-11     Este      Sistemas    Lucas   13374
# 12 2024-02-12    Oeste    Accesorios    Kevin    4744
# 13 2024-02-13    Oeste    Accesorios     Sara    5442
# 14 2024-02-14    Oeste  Dispositivos    Kevin   10711
# 15 2024-02-15    Oeste  Dispositivos     Sara    8780
# ...

# %%
total_ventas = df['Ventas'].sum()
total_ventas
# Out:
# 239533

# %%
euro=4600

# %%
nuevo_df = df.copy()
nuevo_df['Ventas_COP'] = df['Ventas']*euro
nuevo_df
# Out:
#         Fecha   Region      Producto Vendedor  Ventas  Ventas_COP
# 0  2024-01-31  Central    Accesorios    David    8287    38120200
# 1  2024-02-01  Central    Accesorios    Karen    6909    31781400
# 2  2024-02-02  Central  Dispositivos    David   11420    52532000
# 3  2024-02-03  Central  Dispositivos    Karen   12948    59560800
# 4  2024-02-04  Central      Sistemas    David   20098    92450800
# 5  2024-02-05  Central      Sistemas    Karen   30633   140911800
# 6  2024-02-06     Este    Accesorios      Ana    9323    42885800
# 7  2024-02-07     Este    Accesorios    Lucas    7667    35268200
# 8  2024-02-08     Este  Dispositivos      Ana   10348    47600800
# 9  2024-02-09     Este  Dispositivos    Lucas    9312    42835200
# 10 2024-02-10     Este      Sistemas      Ana   13531    62242600
# 11 2024-02-11     Este      Sistemas    Lucas   13374    61520400
# 12 2024-02-12    Oeste    Accesorios    Kevin    4744    21822400
# ...

# %% [markdown]
# #### 1. Mostrar las primeras filas del dataframe

# %%
nuevo_df.head()
# Out:
#        Fecha   Region      Producto Vendedor  Ventas  Ventas_COP
# 0 2024-01-31  Central    Accesorios    David    8287    38120200
# 1 2024-02-01  Central    Accesorios    Karen    6909    31781400
# 2 2024-02-02  Central  Dispositivos    David   11420    52532000
# 3 2024-02-03  Central  Dispositivos    Karen   12948    59560800
# 4 2024-02-04  Central      Sistemas    David   20098    92450800

# %% [markdown]
# #### 2. Calcular el total de ventas por Región

# %%
ventas_region= nuevo_df.groupby('Region')['Ventas_COP'].sum()
ventas_region
# Out:
# Region
# Central    415357000
# Este       292353000
# Oeste      394141800
# Name: Ventas_COP, dtype: int64

# %% [markdown]
# #### 3. Filtrar el dataframe para mostrar solo las ventas realizadas por David

# %%
ventas_david=nuevo_df[nuevo_df['Vendedor']=="David"]
ventas_david
# Out:
#        Fecha   Region      Producto Vendedor  Ventas  Ventas_COP
# 0 2024-01-31  Central    Accesorios    David    8287    38120200
# 2 2024-02-02  Central  Dispositivos    David   11420    52532000
# 4 2024-02-04  Central      Sistemas    David   20098    92450800

# %% [markdown]
# #### 4. Calcular el promedio de ventas por región

# %%
Promedio_region=nuevo_df.groupby('Region')['Ventas_COP'].mean()
Promedio_region
# Out:
# Region
# Central    6.922617e+07
# Este       4.872550e+07
# Oeste      6.569030e+07
# Name: Ventas_COP, dtype: float64

# %% [markdown]
# ####5. Calcular el promedio de ventas por Región con dos decimales

# %%
Promedio_2=nuevo_df.groupby('Region')['Ventas_COP'].mean().round(2)
Promedio_2
# Out:
# Region
# Central    69226166.67
# Este       48725500.00
# Oeste      65690300.00
# Name: Ventas_COP, dtype: float64

# %% [markdown]
# ####6. Ordenar el Dataframe por ventas en orden descendente

# %%
df_ordenado=nuevo_df.sort_values(by='Ventas_COP',ascending=False)
df_ordenado
# Out:
#         Fecha   Region      Producto Vendedor  Ventas  Ventas_COP
# 16 2024-02-16    Oeste      Sistemas    Kevin   32855   151133000
# 5  2024-02-05  Central      Sistemas    Karen   30633   140911800
# 17 2024-02-17    Oeste      Sistemas     Sara   23151   106494600
# 4  2024-02-04  Central      Sistemas    David   20098    92450800
# 10 2024-02-10     Este      Sistemas      Ana   13531    62242600
# 11 2024-02-11     Este      Sistemas    Lucas   13374    61520400
# 3  2024-02-03  Central  Dispositivos    Karen   12948    59560800
# 2  2024-02-02  Central  Dispositivos    David   11420    52532000
# 14 2024-02-14    Oeste  Dispositivos    Kevin   10711    49270600
# 8  2024-02-08     Este  Dispositivos      Ana   10348    47600800
# 6  2024-02-06     Este    Accesorios      Ana    9323    42885800
# 9  2024-02-09     Este  Dispositivos    Lucas    9312    42835200
# 15 2024-02-15    Oeste  Dispositivos     Sara    8780    40388000
# ...

# %% [markdown]
# #### 7. Filtrar ventas mayores a 10000 euros y ordenar de mayor a menor

# %%
df_ventas_orden=nuevo_df[nuevo_df['Ventas']>10000].sort_values(by='Ventas',ascending=False)
df_ventas_orden
# Out:
#         Fecha   Region      Producto Vendedor  Ventas  Ventas_COP
# 16 2024-02-16    Oeste      Sistemas    Kevin   32855   151133000
# 5  2024-02-05  Central      Sistemas    Karen   30633   140911800
# 17 2024-02-17    Oeste      Sistemas     Sara   23151   106494600
# 4  2024-02-04  Central      Sistemas    David   20098    92450800
# 10 2024-02-10     Este      Sistemas      Ana   13531    62242600
# 11 2024-02-11     Este      Sistemas    Lucas   13374    61520400
# 3  2024-02-03  Central  Dispositivos    Karen   12948    59560800
# 2  2024-02-02  Central  Dispositivos    David   11420    52532000
# 14 2024-02-14    Oeste  Dispositivos    Kevin   10711    49270600
# 8  2024-02-08     Este  Dispositivos      Ana   10348    47600800

# %% [markdown]
# #### 8. Eliminar la columna vendendor

# %%
df_eliminado=nuevo_df.drop('Vendedor',axis=1)
df_eliminado
# Out:
#         Fecha   Region      Producto  Ventas  Ventas_COP
# 0  2024-01-31  Central    Accesorios    8287    38120200
# 1  2024-02-01  Central    Accesorios    6909    31781400
# 2  2024-02-02  Central  Dispositivos   11420    52532000
# 3  2024-02-03  Central  Dispositivos   12948    59560800
# 4  2024-02-04  Central      Sistemas   20098    92450800
# 5  2024-02-05  Central      Sistemas   30633   140911800
# 6  2024-02-06     Este    Accesorios    9323    42885800
# 7  2024-02-07     Este    Accesorios    7667    35268200
# 8  2024-02-08     Este  Dispositivos   10348    47600800
# 9  2024-02-09     Este  Dispositivos    9312    42835200
# 10 2024-02-10     Este      Sistemas   13531    62242600
# 11 2024-02-11     Este      Sistemas   13374    61520400
# 12 2024-02-12    Oeste    Accesorios    4744    21822400
# 13 2024-02-13    Oeste    Accesorios    5442    25033200
# 14 2024-02-14    Oeste  Dispositivos   10711    49270600
# ...
